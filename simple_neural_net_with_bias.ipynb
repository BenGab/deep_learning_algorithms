# %%
import tensorflow as tf

# %% [markdown]
# As it seen earlier it will be similar work, but it extends it with bias value.

# %%
X = tf.placeholder(dtype=tf.float32, name='X')
W = tf.Variable(initial_value=tf.random_uniform([1], minval=-10.0, maxval=10.0), name='W')
B = tf.Variable(initial_value=tf.random_uniform([1], minval=-10.0, maxval=10.0), name='B')
Y = X * W + B
Y_ = tf.placeholder(dtype=tf.float32, name='Y_')
Loss = (Y-Y_) ** 2
training_op = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(Loss)
# Out:
# WARNING:tensorflow:From c:\users\gábor\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(500):
        _, w_value, b_value, loss_value = sess.run([training_op, W, B, Loss], feed_dict={X: 1.0, Y_: 2.0})
        print("loss: {}, weight: {}, bias: {}".format(loss_value, w_value, b_value))
# Out:
# loss: [20.367983], weight: [5.128323], bias: [-0.42046893]
# loss: [7.3324747], weight: [4.5867524], bias: [-0.96203977]
# loss: [2.6396914], weight: [4.26181], bias: [-1.2869823]
# loss: [0.9502887], weight: [4.0668445], bias: [-1.4819478]
# loss: [0.342104], weight: [3.949865], bias: [-1.5989271]
# loss: [0.12315737], weight: [3.8796775], bias: [-1.6691147]
# loss: [0.04433665], weight: [3.837565], bias: [-1.7112273]
# loss: [0.01596117], weight: [3.8122973], bias: [-1.7364948]
# loss: [0.00574603], weight: [3.7971368], bias: [-1.7516553]
# loss: [0.00206856], weight: [3.7880404], bias: [-1.7607516]
# loss: [0.00074468], weight: [3.7825825], bias: [-1.7662094]
# loss: [0.00026808], weight: [3.7793078], bias: [-1.769484]
# loss: [9.650703e-05], weight: [3.777343], bias: [-1.7714489]
# loss: [3.4741406e-05], weight: [3.7761643], bias: [-1.7726277]
# loss: [1.2508255e-05], weight: [3.775457], bias: [-1.7733351]
# loss: [4.502567e-06], weight: [3.7750325], bias: [-1.7737595]
# ...
