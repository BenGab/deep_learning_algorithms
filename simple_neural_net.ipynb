# %%
import tensorflow as tf

# %% [markdown]
# Creating a Simple neural network, which uses only one neuron, and just for weights.
# X is input, W is weight as a Variable, Y the output, Y_ the expected output. Loss is (Y-Y_)^2

# %%
X=tf.placeholder(dtype=tf.float32, name='X')
W=tf.Variable(initial_value=tf.random_uniform([1], minval=-10.0, maxval=10.0), name='W')
Y = X*W
Y_ = tf.placeholder(dtype=tf.float32, name='Y_')
Loss = (Y-Y_) ** 2
training_op = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(Loss)
# Out:
# WARNING:tensorflow:From c:\users\gábor\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# Starting training session, which initializes the variables and run the training in 500 epochs

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(500):
        _, w_value, loss_value = sess.run([training_op, W, Loss], feed_dict={X: 1.0, Y_: 2.0})
        print("Loss: {}, Weight: {}".format(loss_value, w_value))
# Out:
# Loss: [79.8298], Weight: [-5.147802]
# Loss: [51.091072], Weight: [-3.7182415]
# Loss: [32.698288], Weight: [-2.574593]
# Loss: [20.9269], Weight: [-1.6596744]
# Loss: [13.393217], Weight: [-0.9277395]
# Loss: [8.571659], Weight: [-0.34219158]
# Loss: [5.485862], Weight: [0.12624678]
# Loss: [3.510951], Weight: [0.5009974]
# Loss: [2.2470088], Weight: [0.80079794]
# Loss: [1.4380856], Weight: [1.0406383]
# Loss: [0.9203748], Weight: [1.2325107]
# Loss: [0.58903986], Weight: [1.3860085]
# Loss: [0.37698555], Weight: [1.5088068]
# Loss: [0.24127074], Weight: [1.6070454]
# Loss: [0.15441331], Weight: [1.6856363]
# Loss: [0.09882455], Weight: [1.748509]
# Loss: [0.0632477], Weight: [1.7988073]
# Loss: [0.04047852], Weight: [1.8390458]
# Loss: [0.02590627], Weight: [1.8712366]
# Loss: [0.01658002], Weight: [1.8969892]
# Loss: [0.01061122], Weight: [1.9175913]
# Loss: [0.00679119], Weight: [1.9340731]
# Loss: [0.00434636], Weight: [1.9472585]
# Loss: [0.00278167], Weight: [1.9578068]
# ...

# %% [markdown]
# As it seems most ranges, does not changes the loss value. So it can cause overfitting, but the real problem is too much range or learning rate.
